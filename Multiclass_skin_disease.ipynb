# %%
import numpy as np          
import pandas as pd         
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.core import Dropout, Activation
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, \
     Dense, Input, Activation, Dropout, GlobalAveragePooling2D, AveragePooling2D
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Model
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import cv2
from cv2 import imread, resize 
from tensorflow.keras.optimizers import Adam
import os

# %%
df_skin = pd.read_csv('/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
df_skin.head(10)
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0    male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0    male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0    male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0    male          ear
# 5  HAM_0001466  ISIC_0027850  bkl   histo  75.0    male          ear
# 6  HAM_0002761  ISIC_0029176  bkl   histo  60.0    male         face
# 7  HAM_0002761  ISIC_0029068  bkl   histo  60.0    male         face
# 8  HAM_0005132  ISIC_0025837  bkl   histo  70.0  female         back
# 9  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back

# %%
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

lesion_ID_dict = {
    'nv': 0,
    'mel': 1,
    'bkl': 2,
    'bcc': 3,
    'akiec': 4,
    'vasc': 5,
    'df': 6
}

# Lesion and it's abbriv.
lesion_names = ['Melanocytic nevi','Melanoma','Benign keratosis-like lesions ',
               'Basal cell carcinoma','Actinic keratoses','Vascular lesions',
               'Dermatofibroma']
lesion_names_short = ['nv','mel','bkl','bcc','akiec','vasc','df']

# Maping the lesion type and ID to a dict.
df_skin['lesion_type']=df_skin['dx'].map(lesion_type_dict)
df_skin['lesion_ID'] = df_skin['dx'].map(lesion_ID_dict)

# Display the total found images.
print('Total number of images', len(df_skin))
print('The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels')

# Display the count of each lesion.
df_skin['lesion_type'].value_counts()
# Out:
# Total number of images 10015
# The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: lesion_type, dtype: int64

# %%
# Reading a random image from our data set
fname_images = np.array(df_skin['image_id'])
file_to_read ='/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_images[13])+'.jpg'

# Resizing the read image to 100x100
img = imread(file_to_read)
img2 = resize(img, (100, 100))

# Show one exampe image before and after
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img[:, :, ::-1])
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(img2[:, :, ::-1])
plt.title('Resized image for DenseNet')
plt.show()

# %%
def produce_new_img(img2: cv2) -> tuple:
    """
    function to reproduse a new manipulated (rotating of flipping the original one)
    image from the read one, To increase the dimension of the dataset, avoiding overfitting of a single class.

    Args:
        img2 (cv2): the read image from cv2 module.

    Returns:
        new_images (tuple): a tuple of the new manipulated images.
    """
    imga = cv2.rotate(img2, cv2.ROTATE_90_CLOCKWISE)
    imgb = cv2.rotate(img2, cv2.ROTATE_90_COUNTERCLOCKWISE)
    imgc = cv2.rotate(img2, cv2.ROTATE_180)
    imgd = cv2.flip(img2, 0)
    imge = cv2.flip(img2, 1)
    new_imges = imga, imgb, imgc, imgd ,imge
    return new_imges

def show_example() -> None:
    """
    Display an image after manipulating it in produce_new_img() function
    """
    plt.figure(figsize = (10, 8))
    plt.subplot(2, 3, 1)
    plt.imshow(img2[:, :, ::-1])
    for i in range(5):
        plt.subplot(2, 3, 2+i)
        plt.imshow(new_img[i][:, :, ::-1])
    plt.tight_layout()
    plt.show()

# Invoking our function :)
new_img = produce_new_img(img2)
# Display an example by invoking show_example func
show_example()

# %%
x = []          
y = []          


lista1 = os.listdir('/skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
lista2 = os.listdir('/skin-cancer-mnist-ham10000/HAM10000_images_part_2/')

# [+] Handling images from part 1 directory
for i in range(len(lista1)):
    # [+] Features: reading and resize the photo.
    fname_image = lista1[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='../input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/' + str(fname_image)  # resolve image name
    img = imread(file_to_read)                                  # read the image 
    img2 = resize(img,(100, 100))                               # resise our image
    x.append(img2)                                              # append the new image to the list x.
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # add more images for class between 1-6, rotating them 
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])

    # inform the user with the number of loaded images each 100 img.
    if i % 100 == 0:
        print(i, 'images loaded')


# [+] Handling images from part 2 directory
for i in range(len(lista2)):

    # [+] Features: reading and resize the photo.
    fname_image = lista2[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='/skin-cancer-mnist-ham10000/HAM10000_images_part_2/' + str(fname_image)


    img = imread(file_to_read)
    img2 = resize(img, (100, 100))
    x.append(img2)
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # [+] Add more images for class between 1-6
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])
    
    if i % 100 == 0: # [+] Inform the user with the number of loaded images each 100 img.
        print(len(lista1) + i,'images loaded')
# Out:
# 0 images loaded
# 100 images loaded
# 200 images loaded
# 300 images loaded
# 400 images loaded
# 500 images loaded
# 600 images loaded
# 700 images loaded
# 800 images loaded
# 1100 images loaded
# 1200 images loaded
# 1500 images loaded
# 1600 images loaded
# 1800 images loaded
# 2100 images loaded
# 2300 images loaded
# 2400 images loaded
# 2600 images loaded
# 2700 images loaded
# 2800 images loaded
# 2900 images loaded
# 3000 images loaded
# 3100 images loaded
# 3200 images loaded
# 3500 images loaded
# 3600 images loaded
# 3700 images loaded
# 3900 images loaded
# 4100 images loaded
# 4500 images loaded
# 4600 images loaded
# 4700 images loaded
# 4800 images loaded
# 4900 images loaded
# 5000 images loaded
# 5100 images loaded
# 5300 images loaded
# 5400 images loaded
# 5700 images loaded
# 5900 images loaded
# 6000 images loaded
# 6100 images loaded
# 6200 images loaded
# 6400 images loaded
# 6600 images loaded
# 6700 images loaded
# 6800 images loaded
# 6900 images loaded
# 7000 images loaded
# 7100 images loaded
# 7200 images loaded
# 7300 images loaded
# 7400 images loaded
# 7500 images loaded
# 7600 images loaded
# 7700 images loaded
# 7800 images loaded
# 8000 images loaded
# 8100 images loaded
# 8300 images loaded
# 8400 images loaded
# 8700 images loaded
# 8900 images loaded
# 9100 images loaded
# 9200 images loaded
# 9400 images loaded
# 9500 images loaded
# 9600 images loaded
# 9700 images loaded
# 9800 images loaded
# 9900 images loaded

# %%
x = np.array(x)
y = np.array(y)

# convert y (targets) array as required by softmax activation function
y_train = to_categorical(y, num_classes = 7)

# %%
# split in 80% training and 20% test data
X_train, X_test, y_train, y_test = train_test_split(x,                  # Images array.
                                                    y_train,            # The training set.
                                                    test_size = 0.20,   # Split data set into 20/80.
                                                    random_state = 50,  # Shuffling number to random the set.
                                                    stratify = y)       # Mix training and test sets.
# [+] Display the count of train/test data set.
print('Train dataset shape', X_train.shape)
print('Test dataset shape', X_test.shape)
# Out:
# Train dataset shape (21252, 100, 100, 3)
# Test dataset shape (5313, 100, 100, 3)

# %%
def show_neg_figuers() -> None:
    """ Display negative figuers of the classes. """
    # Figure, Axes
    _, ax = plt.subplots(1, 7, figsize = (30, 30))
    for i in range(7):
        ax[i].set_axis_off()                                    # set the image to negative.
        ax[i].imshow(X_train[i])                                # Display the img.
        ax[i].set_title(lesion_names[np.argmax(y_train[i])])    # Set image title.

show_neg_figuers()

# %%
def est_class_weights(dis_id: np.array) -> dict:
    """Estimate class weights for unbalanced datasets.

    Args:
        dis_id (np.array): numpy array of dis IDs

    Returns:
        dict: Estimated class weights for for unbalanced datasets.
    """
    class_weights = np.around(compute_class_weight(class_weight = 'balanced', classes = np.unique(dis_id), y = y), 2)
    class_weights = dict(zip(np.unique(dis_id), class_weights))

y_id = np.array(df_skin['lesion_ID'])
new_class_weights = est_class_weights(y_id)
print('The problem is unbalanced. We need to provide class-weights')
print(new_class_weights)
# Out:
# The problem is unbalanced. We need to provide class-weights
# None

# %%
import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
import itertools
from tensorflow.keras.layers import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding

# %%
model = Sequential()
        
# [+] 1st convolutional layer
model.add(Conv2D(filters = 96,
                kernel_size = (11, 11),
                strides = (4, 4),
                activation = 'relu',
                input_shape = (100, 100, 3)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 2nd convolutional layer
model.add(Conv2D(filters = 256,
                kernel_size=(5, 5),
                strides=(1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 3rd convolutional layer
model.add(Conv2D(filters = 384,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 padding="same"))
model.add(BatchNormalization())

# [+] 4th convolutional layer
model.add(Conv2D(filters = 384,
                kernel_size = (1, 1), 
                strides = (1, 1), 
                activation = 'relu', 
                padding = "same"))
model.add(BatchNormalization())

# [+] 5th convolutional layer
model.add(Conv2D(filters = 256, 
                kernel_size = (1, 1),
                strides = (1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))
              
model.add(Flatten())  # [+] Convert the Conv2D objects into one List.

# [+] 6th, Dense layer:
# From the Docs: 
# A Dense layer feeds all outputs from the previous layer to all its neurons,
# each neuron providing one output to the next layer.
# source: www.stackoverflow.com
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 7th Dense layer
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 8th output layer
model.add(Dense(7, activation = 'softmax'))
# Out:
# 2022-10-26 10:38:11.190310: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:11.284227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:11.285023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:11.286455: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 10:38:11.286835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:11.287599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:11.288233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:13.495036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:13.495991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:13.496730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 10:38:13.497318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
##########################
### [+] Training phase ###
##########################

def mod_checkpoint_callback() -> None:
    """
    Saving our model
    
    Returns:
        None: Saving a checkpoint of the model.
    """
    trained_model = ModelCheckpoint(filepath = 'model.h5',  # result file name
                             save_weights_only = False,     # Save all training results/params.
                             monitor = 'val_accuracy',      # check our model accuracy if it's step forward.
                             mode = 'auto',                 # enable auto save.
                             save_best_only = True,         # if ac_new > ac_old
                             verbose = 1)
    return trained_model

# Montoring the training procces in each epoch.
early_stopping_monitor = EarlyStopping(patience = 100, monitor = 'val_accuracy')

model_checkpoint_callback = mod_checkpoint_callback()

# Estimate the model data if it was big one.
optimizer = Adam(lr = 0.0001, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-3)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip = True, shear_range = 0.2)
datagen.fit(X_train)

batch_size = 32     # samples in the network at once.
epochs = 100        # epochs number.

# org model result data
history = model.fit(datagen.flow(X_train,y_train),
                    epochs = epochs,
                    batch_size = batch_size,
                    shuffle = True,
                    callbacks = [early_stopping_monitor, model_checkpoint_callback],
                    validation_data = (X_test, y_test),
                    class_weight = new_class_weights
                )
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 2022-10-26 10:38:17.572353: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-10-26 10:38:19.370521: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 665/665 [==============================] - 60s 78ms/step - loss: 1.4187 - accuracy: 0.4873 - val_loss: 1.6704 - val_accuracy: 0.4705
#
# Epoch 00001: val_accuracy improved from -inf to 0.47054, saving model to model.h5
# Epoch 2/100
# 665/665 [==============================] - 50s 76ms/step - loss: 1.1213 - accuracy: 0.5644 - val_loss: 1.1535 - val_accuracy: 0.5236
#
# Epoch 00002: val_accuracy improved from 0.47054 to 0.52362, saving model to model.h5
# Epoch 3/100
# 665/665 [==============================] - 51s 76ms/step - loss: 1.0385 - accuracy: 0.5988 - val_loss: 1.7288 - val_accuracy: 0.4807
#
# Epoch 00003: val_accuracy did not improve from 0.52362
# Epoch 4/100
# 665/665 [==============================] - 51s 77ms/step - loss: 0.9783 - accuracy: 0.6180 - val_loss: 0.9549 - val_accuracy: 0.6260
#
# Epoch 00004: val_accuracy improved from 0.52362 to 0.62601, saving model to model.h5
# Epoch 5/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.9321 - accuracy: 0.6339 - val_loss: 1.0286 - val_accuracy: 0.5931
#
# Epoch 00005: val_accuracy did not improve from 0.62601
# Epoch 6/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.8898 - accuracy: 0.6505 - val_loss: 0.9561 - val_accuracy: 0.6320
#
# Epoch 00006: val_accuracy improved from 0.62601 to 0.63203, saving model to model.h5
# Epoch 7/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.8543 - accuracy: 0.6654 - val_loss: 0.9854 - val_accuracy: 0.5884
#
# Epoch 00007: val_accuracy did not improve from 0.63203
# Epoch 8/100
# 665/665 [==============================] - 51s 77ms/step - loss: 0.8314 - accuracy: 0.6745 - val_loss: 0.9448 - val_accuracy: 0.6322
#
# Epoch 00008: val_accuracy improved from 0.63203 to 0.63222, saving model to model.h5
# Epoch 9/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.7969 - accuracy: 0.6827 - val_loss: 1.0284 - val_accuracy: 0.5931
#
# Epoch 00009: val_accuracy did not improve from 0.63222
# Epoch 10/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.7689 - accuracy: 0.6972 - val_loss: 0.8664 - val_accuracy: 0.6550
#
# Epoch 00010: val_accuracy improved from 0.63222 to 0.65500, saving model to model.h5
# Epoch 11/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.7292 - accuracy: 0.7145 - val_loss: 0.7955 - val_accuracy: 0.6876
#
# Epoch 00011: val_accuracy improved from 0.65500 to 0.68756, saving model to model.h5
# Epoch 12/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.7020 - accuracy: 0.7261 - val_loss: 1.0449 - val_accuracy: 0.6066
#
# Epoch 00012: val_accuracy did not improve from 0.68756
# Epoch 13/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.6676 - accuracy: 0.7367 - val_loss: 1.1841 - val_accuracy: 0.5327
#
# Epoch 00013: val_accuracy did not improve from 0.68756
# Epoch 14/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.6409 - accuracy: 0.7513 - val_loss: 1.3292 - val_accuracy: 0.5645
#
# Epoch 00014: val_accuracy did not improve from 0.68756
# Epoch 15/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.6186 - accuracy: 0.7564 - val_loss: 0.8283 - val_accuracy: 0.6721
#
# Epoch 00015: val_accuracy did not improve from 0.68756
# Epoch 16/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.5920 - accuracy: 0.7700 - val_loss: 1.3039 - val_accuracy: 0.5441
#
# Epoch 00016: val_accuracy did not improve from 0.68756
# Epoch 17/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.5554 - accuracy: 0.7831 - val_loss: 0.7386 - val_accuracy: 0.7133
#
# Epoch 00017: val_accuracy improved from 0.68756 to 0.71334, saving model to model.h5
# Epoch 18/100
# 665/665 [==============================] - 51s 77ms/step - loss: 0.5365 - accuracy: 0.7930 - val_loss: 1.5102 - val_accuracy: 0.5456
#
# Epoch 00018: val_accuracy did not improve from 0.71334
# Epoch 19/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.5088 - accuracy: 0.8010 - val_loss: 0.6969 - val_accuracy: 0.7371
#
# Epoch 00019: val_accuracy improved from 0.71334 to 0.73706, saving model to model.h5
# Epoch 20/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.4930 - accuracy: 0.8065 - val_loss: 0.7756 - val_accuracy: 0.7092
#
# Epoch 00020: val_accuracy did not improve from 0.73706
# Epoch 21/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.4684 - accuracy: 0.8184 - val_loss: 0.6531 - val_accuracy: 0.7619
#
# Epoch 00021: val_accuracy improved from 0.73706 to 0.76190, saving model to model.h5
# Epoch 22/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.4506 - accuracy: 0.8256 - val_loss: 0.7267 - val_accuracy: 0.7433
#
# Epoch 00022: val_accuracy did not improve from 0.76190
# Epoch 23/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.4277 - accuracy: 0.8342 - val_loss: 1.8432 - val_accuracy: 0.5658
#
# Epoch 00023: val_accuracy did not improve from 0.76190
# Epoch 24/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.4016 - accuracy: 0.8460 - val_loss: 2.2719 - val_accuracy: 0.5289
#
# Epoch 00024: val_accuracy did not improve from 0.76190
# Epoch 25/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.3934 - accuracy: 0.8497 - val_loss: 1.0534 - val_accuracy: 0.6761
#
# Epoch 00025: val_accuracy did not improve from 0.76190
# Epoch 26/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.3647 - accuracy: 0.8616 - val_loss: 0.6034 - val_accuracy: 0.7781
#
# Epoch 00026: val_accuracy improved from 0.76190 to 0.77809, saving model to model.h5
# Epoch 27/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.3510 - accuracy: 0.8667 - val_loss: 0.7498 - val_accuracy: 0.7346
#
# Epoch 00027: val_accuracy did not improve from 0.77809
# Epoch 28/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.3490 - accuracy: 0.8694 - val_loss: 0.7353 - val_accuracy: 0.7421
#
# Epoch 00028: val_accuracy did not improve from 0.77809
# Epoch 29/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.3288 - accuracy: 0.8740 - val_loss: 0.9212 - val_accuracy: 0.7133
#
# Epoch 00029: val_accuracy did not improve from 0.77809
# Epoch 30/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.3142 - accuracy: 0.8811 - val_loss: 0.9068 - val_accuracy: 0.7036
#
# Epoch 00030: val_accuracy did not improve from 0.77809
# Epoch 31/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.3135 - accuracy: 0.8800 - val_loss: 0.6116 - val_accuracy: 0.7867
#
# Epoch 00031: val_accuracy improved from 0.77809 to 0.78675, saving model to model.h5
# Epoch 32/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.2952 - accuracy: 0.8878 - val_loss: 0.7653 - val_accuracy: 0.7489
#
# Epoch 00032: val_accuracy did not improve from 0.78675
# Epoch 33/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.2894 - accuracy: 0.8908 - val_loss: 0.6132 - val_accuracy: 0.7935
#
# Epoch 00033: val_accuracy improved from 0.78675 to 0.79353, saving model to model.h5
# Epoch 34/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.2807 - accuracy: 0.8935 - val_loss: 0.5215 - val_accuracy: 0.8142
#
# Epoch 00034: val_accuracy improved from 0.79353 to 0.81423, saving model to model.h5
# Epoch 35/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.2631 - accuracy: 0.9002 - val_loss: 0.7460 - val_accuracy: 0.7367
#
# Epoch 00035: val_accuracy did not improve from 0.81423
# Epoch 36/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.2483 - accuracy: 0.9055 - val_loss: 0.5118 - val_accuracy: 0.8268
#
# Epoch 00036: val_accuracy improved from 0.81423 to 0.82684, saving model to model.h5
# Epoch 37/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.2464 - accuracy: 0.9039 - val_loss: 0.7707 - val_accuracy: 0.7581
#
# Epoch 00037: val_accuracy did not improve from 0.82684
# Epoch 38/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.2371 - accuracy: 0.9097 - val_loss: 0.6617 - val_accuracy: 0.7901
#
# Epoch 00038: val_accuracy did not improve from 0.82684
# Epoch 39/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.2375 - accuracy: 0.9114 - val_loss: 0.5379 - val_accuracy: 0.8221
#
# Epoch 00039: val_accuracy did not improve from 0.82684
# Epoch 40/100
# 665/665 [==============================] - 50s 74ms/step - loss: 0.2237 - accuracy: 0.9158 - val_loss: 0.8638 - val_accuracy: 0.7497
#
# Epoch 00040: val_accuracy did not improve from 0.82684
# Epoch 41/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.2250 - accuracy: 0.9157 - val_loss: 0.4683 - val_accuracy: 0.8455
#
# Epoch 00041: val_accuracy improved from 0.82684 to 0.84547, saving model to model.h5
# Epoch 42/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.2120 - accuracy: 0.9228 - val_loss: 0.4178 - val_accuracy: 0.8541
#
# Epoch 00042: val_accuracy improved from 0.84547 to 0.85413, saving model to model.h5
# Epoch 43/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.2045 - accuracy: 0.9237 - val_loss: 0.8068 - val_accuracy: 0.7623
#
# Epoch 00043: val_accuracy did not improve from 0.85413
# Epoch 44/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.1950 - accuracy: 0.9273 - val_loss: 0.7503 - val_accuracy: 0.7741
#
# Epoch 00044: val_accuracy did not improve from 0.85413
# Epoch 45/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1894 - accuracy: 0.9298 - val_loss: 1.3974 - val_accuracy: 0.6661
#
# Epoch 00045: val_accuracy did not improve from 0.85413
# Epoch 46/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.1876 - accuracy: 0.9319 - val_loss: 1.1073 - val_accuracy: 0.7135
#
# Epoch 00046: val_accuracy did not improve from 0.85413
# Epoch 47/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1798 - accuracy: 0.9336 - val_loss: 0.5027 - val_accuracy: 0.8374
#
# Epoch 00047: val_accuracy did not improve from 0.85413
# Epoch 48/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1713 - accuracy: 0.9359 - val_loss: 0.8671 - val_accuracy: 0.7553
#
# Epoch 00048: val_accuracy did not improve from 0.85413
# Epoch 49/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1702 - accuracy: 0.9358 - val_loss: 0.5023 - val_accuracy: 0.8466
#
# Epoch 00049: val_accuracy did not improve from 0.85413
# Epoch 50/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1827 - accuracy: 0.9326 - val_loss: 1.7324 - val_accuracy: 0.6452
#
# Epoch 00050: val_accuracy did not improve from 0.85413
# Epoch 51/100
# 665/665 [==============================] - 50s 74ms/step - loss: 0.1624 - accuracy: 0.9400 - val_loss: 0.4449 - val_accuracy: 0.8539
#
# Epoch 00051: val_accuracy did not improve from 0.85413
# Epoch 52/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.1582 - accuracy: 0.9438 - val_loss: 0.6589 - val_accuracy: 0.8063
#
# Epoch 00052: val_accuracy did not improve from 0.85413
# Epoch 53/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1496 - accuracy: 0.9455 - val_loss: 4.0644 - val_accuracy: 0.4993
#
# Epoch 00053: val_accuracy did not improve from 0.85413
# Epoch 54/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1612 - accuracy: 0.9401 - val_loss: 0.9203 - val_accuracy: 0.7608
#
# Epoch 00054: val_accuracy did not improve from 0.85413
# Epoch 55/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1488 - accuracy: 0.9451 - val_loss: 0.7939 - val_accuracy: 0.7886
#
# Epoch 00055: val_accuracy did not improve from 0.85413
# Epoch 56/100
# 665/665 [==============================] - 51s 77ms/step - loss: 0.1539 - accuracy: 0.9441 - val_loss: 0.3590 - val_accuracy: 0.8891
#
# Epoch 00056: val_accuracy improved from 0.85413 to 0.88914, saving model to model.h5
# Epoch 57/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1373 - accuracy: 0.9505 - val_loss: 0.5401 - val_accuracy: 0.8421
#
# Epoch 00057: val_accuracy did not improve from 0.88914
# Epoch 58/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.1580 - accuracy: 0.9423 - val_loss: 0.6396 - val_accuracy: 0.8152
#
# Epoch 00058: val_accuracy did not improve from 0.88914
# Epoch 59/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.1316 - accuracy: 0.9515 - val_loss: 0.3268 - val_accuracy: 0.8922
#
# Epoch 00059: val_accuracy improved from 0.88914 to 0.89215, saving model to model.h5
# Epoch 60/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1249 - accuracy: 0.9554 - val_loss: 0.5570 - val_accuracy: 0.8410
#
# Epoch 00060: val_accuracy did not improve from 0.89215
# Epoch 61/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.1297 - accuracy: 0.9524 - val_loss: 0.3990 - val_accuracy: 0.8745
#
# Epoch 00061: val_accuracy did not improve from 0.89215
# Epoch 62/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1303 - accuracy: 0.9540 - val_loss: 0.5272 - val_accuracy: 0.8492
#
# Epoch 00062: val_accuracy did not improve from 0.89215
# Epoch 63/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1177 - accuracy: 0.9580 - val_loss: 1.1606 - val_accuracy: 0.7175
#
# Epoch 00063: val_accuracy did not improve from 0.89215
# Epoch 64/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1261 - accuracy: 0.9556 - val_loss: 1.0471 - val_accuracy: 0.7506
#
# Epoch 00064: val_accuracy did not improve from 0.89215
# Epoch 65/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1274 - accuracy: 0.9538 - val_loss: 0.8503 - val_accuracy: 0.7698
#
# Epoch 00065: val_accuracy did not improve from 0.89215
# Epoch 66/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1274 - accuracy: 0.9564 - val_loss: 0.7029 - val_accuracy: 0.8172
#
# Epoch 00066: val_accuracy did not improve from 0.89215
# Epoch 67/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1182 - accuracy: 0.9571 - val_loss: 0.3358 - val_accuracy: 0.9016
#
# Epoch 00067: val_accuracy improved from 0.89215 to 0.90156, saving model to model.h5
# Epoch 68/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.1306 - accuracy: 0.9535 - val_loss: 2.0597 - val_accuracy: 0.5978
#
# Epoch 00068: val_accuracy did not improve from 0.90156
# Epoch 69/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1102 - accuracy: 0.9591 - val_loss: 0.5493 - val_accuracy: 0.8573
#
# Epoch 00069: val_accuracy did not improve from 0.90156
# Epoch 70/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1076 - accuracy: 0.9626 - val_loss: 0.7093 - val_accuracy: 0.8201
#
# Epoch 00070: val_accuracy did not improve from 0.90156
# Epoch 71/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.0942 - accuracy: 0.9656 - val_loss: 0.9689 - val_accuracy: 0.7858
#
# Epoch 00071: val_accuracy did not improve from 0.90156
# Epoch 72/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.1027 - accuracy: 0.9616 - val_loss: 1.2185 - val_accuracy: 0.7224
#
# Epoch 00072: val_accuracy did not improve from 0.90156
# Epoch 73/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.1124 - accuracy: 0.9607 - val_loss: 1.1700 - val_accuracy: 0.7357
#
# Epoch 00073: val_accuracy did not improve from 0.90156
# Epoch 74/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.1008 - accuracy: 0.9632 - val_loss: 0.6904 - val_accuracy: 0.8091
#
# Epoch 00074: val_accuracy did not improve from 0.90156
# Epoch 75/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.1025 - accuracy: 0.9634 - val_loss: 0.4381 - val_accuracy: 0.8805
#
# Epoch 00075: val_accuracy did not improve from 0.90156
# Epoch 76/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.1096 - accuracy: 0.9609 - val_loss: 0.4122 - val_accuracy: 0.8856
#
# Epoch 00076: val_accuracy did not improve from 0.90156
# Epoch 77/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.0956 - accuracy: 0.9660 - val_loss: 0.4207 - val_accuracy: 0.8784
#
# Epoch 00077: val_accuracy did not improve from 0.90156
# Epoch 78/100
# 665/665 [==============================] - 52s 78ms/step - loss: 0.0917 - accuracy: 0.9663 - val_loss: 0.4848 - val_accuracy: 0.8624
#
# Epoch 00078: val_accuracy did not improve from 0.90156
# Epoch 79/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.0978 - accuracy: 0.9664 - val_loss: 0.8874 - val_accuracy: 0.7738
#
# Epoch 00079: val_accuracy did not improve from 0.90156
# Epoch 80/100
# 665/665 [==============================] - 50s 74ms/step - loss: 0.0940 - accuracy: 0.9662 - val_loss: 0.7871 - val_accuracy: 0.8110
#
# Epoch 00080: val_accuracy did not improve from 0.90156
# Epoch 81/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.0880 - accuracy: 0.9690 - val_loss: 0.7217 - val_accuracy: 0.8107
#
# Epoch 00081: val_accuracy did not improve from 0.90156
# Epoch 82/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0842 - accuracy: 0.9698 - val_loss: 1.5702 - val_accuracy: 0.6923
#
# Epoch 00082: val_accuracy did not improve from 0.90156
# Epoch 83/100
# 665/665 [==============================] - 51s 77ms/step - loss: 0.0871 - accuracy: 0.9689 - val_loss: 0.7127 - val_accuracy: 0.8191
#
# Epoch 00083: val_accuracy did not improve from 0.90156
# Epoch 84/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.0924 - accuracy: 0.9664 - val_loss: 0.5850 - val_accuracy: 0.8586
#
# Epoch 00084: val_accuracy did not improve from 0.90156
# Epoch 85/100
# 665/665 [==============================] - 50s 74ms/step - loss: 0.0769 - accuracy: 0.9736 - val_loss: 1.1966 - val_accuracy: 0.7438
#
# Epoch 00085: val_accuracy did not improve from 0.90156
# Epoch 86/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.0846 - accuracy: 0.9704 - val_loss: 0.3082 - val_accuracy: 0.9048
#
# Epoch 00086: val_accuracy improved from 0.90156 to 0.90476, saving model to model.h5
# Epoch 87/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0848 - accuracy: 0.9697 - val_loss: 0.3817 - val_accuracy: 0.8948
#
# Epoch 00087: val_accuracy did not improve from 0.90476
# Epoch 88/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0752 - accuracy: 0.9727 - val_loss: 1.5668 - val_accuracy: 0.7030
#
# Epoch 00088: val_accuracy did not improve from 0.90476
# Epoch 89/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.0866 - accuracy: 0.9692 - val_loss: 0.4664 - val_accuracy: 0.8726
#
# Epoch 00089: val_accuracy did not improve from 0.90476
# Epoch 90/100
# 665/665 [==============================] - 48s 73ms/step - loss: 0.0774 - accuracy: 0.9735 - val_loss: 0.4016 - val_accuracy: 0.8970
#
# Epoch 00090: val_accuracy did not improve from 0.90476
# Epoch 91/100
# 665/665 [==============================] - 50s 74ms/step - loss: 0.0734 - accuracy: 0.9754 - val_loss: 0.4796 - val_accuracy: 0.8795
#
# Epoch 00091: val_accuracy did not improve from 0.90476
# Epoch 92/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.0779 - accuracy: 0.9718 - val_loss: 0.5737 - val_accuracy: 0.8487
#
# Epoch 00092: val_accuracy did not improve from 0.90476
# Epoch 93/100
# 665/665 [==============================] - 51s 76ms/step - loss: 0.0748 - accuracy: 0.9733 - val_loss: 0.3785 - val_accuracy: 0.8976
#
# Epoch 00093: val_accuracy did not improve from 0.90476
# Epoch 94/100
# 665/665 [==============================] - 49s 73ms/step - loss: 0.0835 - accuracy: 0.9725 - val_loss: 0.8749 - val_accuracy: 0.8059
#
# Epoch 00094: val_accuracy did not improve from 0.90476
# Epoch 95/100
# 665/665 [==============================] - 50s 76ms/step - loss: 0.0805 - accuracy: 0.9730 - val_loss: 0.4284 - val_accuracy: 0.8746
#
# Epoch 00095: val_accuracy did not improve from 0.90476
# Epoch 96/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0811 - accuracy: 0.9708 - val_loss: 0.3408 - val_accuracy: 0.9006
#
# Epoch 00096: val_accuracy did not improve from 0.90476
# Epoch 97/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0652 - accuracy: 0.9768 - val_loss: 0.3083 - val_accuracy: 0.9117
#
# Epoch 00097: val_accuracy improved from 0.90476 to 0.91173, saving model to model.h5
# Epoch 98/100
# 665/665 [==============================] - 50s 75ms/step - loss: 0.0650 - accuracy: 0.9772 - val_loss: 0.3812 - val_accuracy: 0.9044
#
# Epoch 00098: val_accuracy did not improve from 0.91173
# Epoch 99/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0707 - accuracy: 0.9751 - val_loss: 0.7816 - val_accuracy: 0.8105
#
# Epoch 00099: val_accuracy did not improve from 0.91173
# Epoch 100/100
# 665/665 [==============================] - 49s 74ms/step - loss: 0.0688 - accuracy: 0.9750 - val_loss: 0.4471 - val_accuracy: 0.8730
#
# Epoch 00100: val_accuracy did not improve from 0.91173

# %%
# [+] inform the user with model Accuracy %
scores = model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 [==============================] - 1s 5ms/step - loss: 0.4471 - accuracy: 0.8730
# Accuracy: 87.30%

# %%
def display_accuracy() -> None:
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
    plt.show()

def display_loss() -> None:
    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

display_accuracy()
display_loss()

# %%
y_pred = model.predict(X_test)

def test_model() -> tuple:
    """ Tunning the accurate results and inaccurate results

    Returns:
        (total, accurate) [tuple]: tuple of total tested test-cases, accurate
    """
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []
    for i in range(len(y_pred)):
        if np.argmax(y_pred[i]) == np.argmax(y_test[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1
    return (total, accurate)

total, accurate = test_model()
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate / total * 100, 3), '%')
# Out:
# Total-test-data; 5313 	accurately-predicted-data: 4638 	 wrongly-predicted-data:  675
# Accuracy: 87.295 %

# %%
best_model = load_model('./model.h5')

# Compute predictions
y_pred_prob = np.around(best_model.predict(X_test),3)
y_pred = np.argmax(y_pred_prob, axis = 1)
y_test2 = np.argmax(y_test, axis = 1)

# %%
# [+] inform the user with model Accuracy %
scores = best_model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 [==============================] - 1s 5ms/step - loss: 0.3083 - accuracy: 0.9117
# Accuracy: 91.17%

# %%
plt.figure(figsize=(16,16))
for i in range(16):
    plt.subplot(4,4,i+1)
    index = i+100
    plt.imshow(X_test[index,:,:,::-1])
    label_exp = lesion_names[y_test2[index]]  #expected label
    label_pred = lesion_names[y_pred[index]]  #predicted label
    label_pred_prob = round(np.max(y_pred_prob[index])*100)
    plt.title('Expected:'+str(label_exp)+'\n Pred.:'+str(label_pred)+' ('+str(label_pred_prob)+'%)')
plt.ylabel('')
plt.tight_layout()
plt.savefig('final_figure.png',dpi=300)
plt.show()

# %%
#Accuracy for each type
acc_tot= []

for i in range(7):
    acc_parz = round(np.mean(y_test2[y_test2 == i] == y_pred[y_test2 == i]),2)
    lab_parz = lesion_names[i]
    print('accuracy for',lab_parz,'=',acc_parz)
    acc_tot.append(acc_parz)
# Out:
# accuracy for Melanocytic nevi = 0.89
# accuracy for Melanoma = 0.9
# accuracy for Benign keratosis-like lesions  = 0.91
# accuracy for Basal cell carcinoma = 0.94
# accuracy for Actinic keratoses = 0.93
# accuracy for Vascular lesions = 0.95
# accuracy for Dermatofibroma = 0.93

# %%
acc_tot = np.array(acc_tot)
freq = np.unique(y_test2,return_counts=True)[1]

np.sum(acc_tot*freq)/np.sum(freq)
# Out:
# 0.9091963109354414
